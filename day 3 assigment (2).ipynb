# %%
#ASSIGMENT 1 DAY 3

# %%
altitude = 6000
if altitude<=1000:
    print("safe to lande")
elif altitude<=5000:
    print("down to 1000feet")   
else:
    print("go around and try later")
# Out:
# go around and try later

# %%
altitude=2500
if altitude<=1000:
    print("safe to land")
elif altitude<=5000:
    print("come down to 1000ft")
else:
    print("go around and try again")
# Out:
# come down to 1000ft

# %%
alitude=1000
if altitude<=1000:
    print("safe to world")
elif altitude<=5000:
    print("down to 1000ft")
else:
    print("go around and try again")
# Out:
# down to 1000ft

# %% [markdown]
# #ASSIGMENT 2 DAY 3

# %%
lower=1
upper =200
for num in range (lower,upper+1):
    if num <1:
        for i in range (2,num):
            if (num % 1) == 0:
                break                       
    else:   
        print (num,"is a prime")
# Out:
# 1 is a prime
# 2 is a prime
# 3 is a prime
# 4 is a prime
# 5 is a prime
# 6 is a prime
# 7 is a prime
# 8 is a prime
# 9 is a prime
# 10 is a prime
# 11 is a prime
# 12 is a prime
# 13 is a prime
# 14 is a prime
# 15 is a prime
# 16 is a prime
# 17 is a prime
# 18 is a prime
# 19 is a prime
# 20 is a prime
# 21 is a prime
# 22 is a prime
# 23 is a prime
# 24 is a prime
# 25 is a prime
# 26 is a prime
# 27 is a prime
# 28 is a prime
# 29 is a prime
# 30 is a prime
# 31 is a prime
# 32 is a prime
# 33 is a prime
# 34 is a prime
# 35 is a prime
# 36 is a prime
# 37 is a prime
# 38 is a prime
# 39 is a prime
# 40 is a prime
# 41 is a prime
# 42 is a prime
# 43 is a prime
# 44 is a prime
# 45 is a prime
# 46 is a prime
# 47 is a prime
# 48 is a prime
# 49 is a prime
# 50 is a prime
# 51 is a prime
# 52 is a prime
# 53 is a prime
# 54 is a prime
# 55 is a prime
# 56 is a prime
# 57 is a prime
# 58 is a prime
# 59 is a prime
# 60 is a prime
# 61 is a prime
# 62 is a prime
# 63 is a prime
# 64 is a prime
# 65 is a prime
# 66 is a prime
# 67 is a prime
# 68 is a prime
# 69 is a prime
# 70 is a prime
# 71 is a prime
# 72 is a prime
# 73 is a prime
# 74 is a prime
# 75 is a prime
# 76 is a prime
# 77 is a prime
# 78 is a prime
# 79 is a prime
# 80 is a prime
# 81 is a prime
# 82 is a prime
# 83 is a prime
# 84 is a prime
# 85 is a prime
# 86 is a prime
# 87 is a prime
# 88 is a prime
# 89 is a prime
# 90 is a prime
# 91 is a prime
# 92 is a prime
# 93 is a prime
# 94 is a prime
# 95 is a prime
# 96 is a prime
# 97 is a prime
# 98 is a prime
# 99 is a prime
# 100 is a prime
# 101 is a prime
# 102 is a prime
# 103 is a prime
# 104 is a prime
# 105 is a prime
# 106 is a prime
# 107 is a prime
# 108 is a prime
# 109 is a prime
# 110 is a prime
# 111 is a prime
# 112 is a prime
# 113 is a prime
# 114 is a prime
# 115 is a prime
# 116 is a prime
# 117 is a prime
# 118 is a prime
# 119 is a prime
# 120 is a prime
# 121 is a prime
# 122 is a prime
# 123 is a prime
# 124 is a prime
# 125 is a prime
# 126 is a prime
# 127 is a prime
# 128 is a prime
# 129 is a prime
# 130 is a prime
# 131 is a prime
# 132 is a prime
# 133 is a prime
# 134 is a prime
# 135 is a prime
# 136 is a prime
# 137 is a prime
# 138 is a prime
# 139 is a prime
# 140 is a prime
# 141 is a prime
# 142 is a prime
# 143 is a prime
# 144 is a prime
# 145 is a prime
# 146 is a prime
# 147 is a prime
# 148 is a prime
# 149 is a prime
# 150 is a prime
# 151 is a prime
# 152 is a prime
# 153 is a prime
# 154 is a prime
# 155 is a prime
# 156 is a prime
# 157 is a prime
# 158 is a prime
# 159 is a prime
# 160 is a prime
# 161 is a prime
# 162 is a prime
# 163 is a prime
# 164 is a prime
# 165 is a prime
# 166 is a prime
# 167 is a prime
# 168 is a prime
# 169 is a prime
# 170 is a prime
# 171 is a prime
# 172 is a prime
# 173 is a prime
# 174 is a prime
# 175 is a prime
# 176 is a prime
# 177 is a prime
# 178 is a prime
# 179 is a prime
# 180 is a prime
# 181 is a prime
# 182 is a prime
# 183 is a prime
# 184 is a prime
# 185 is a prime
# 186 is a prime
# 187 is a prime
# 188 is a prime
# 189 is a prime
# 190 is a prime
# 191 is a prime
# 192 is a prime
# 193 is a prime
# 194 is a prime
# 195 is a prime
# 196 is a prime
# 197 is a prime
# 198 is a prime
# 199 is a prime
# 200 is a prime
